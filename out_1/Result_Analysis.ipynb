# %%
import pandas as pd
import astropy
from astropy.io import ascii

# %%
observations = ascii.read('observations.txt')
observations
# Out:
# <Table length=74>
#    id    redshift xray_boxcar_2to7keV ... PACS_red    PACS_red_err
#  int32   float64        float64       ... float64       float64
# -------- -------- ------------------- ... -------- -----------------
# 61006530      1.1           1.439e-06 ...      nan               nan
# 61006993      0.3           1.688e-06 ...      nan               nan
# 61007097      0.2           2.487e-06 ...      nan               nan
# 61007100      1.5           1.675e-06 ...      nan               nan
# 61007776      1.7           4.972e-07 ...    55.27 7.975602108931965
# 61007815      1.0           1.194e-06 ...      nan               nan
# 61008115      1.2           6.246e-07 ...      nan               nan
# 61008262      1.4            3.07e-07 ...      nan               nan
# 61008428      1.1           1.047e-06 ...      nan               nan
# 61008665      1.2           6.238e-07 ...      nan               nan
# ...

# %%
results = ascii.read('results.txt')
results
# Out:
# <Table length=74>
#    id      bayes.sfh.sfr    ...  best.PACS_green     best.PACS_red
#  int32        float64       ...      float64            float64
# -------- ------------------ ... ------------------ ------------------
# 61006530   67.3588415028716 ... 2.9290734609425457  5.847742535805008
# 61006993  8.823238874342124 ... 11.412131366105069 15.374276221688854
# 61007097  2.406717130310602 ...  8.055027904091052  9.698526054183827
# 61007100                nan ...                nan                nan
# 61007776                nan ...                nan                nan
# 61007815   4.60282249858343 ... 0.2658113014077614 0.5136301860815826
# 61008115   80.3374087209996 ... 2.6762026783171984  5.519894330727634
# 61008262                nan ...                nan                nan
# 61008428 16.964456392297464 ... 0.7385810713931581 1.4745386228505124
# 61008665 16.972960650725827 ... 0.5671207720142682  1.169734549495283
# ...
