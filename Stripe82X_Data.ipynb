# %%
import pandas as pd
from astropy.io import fits
from astropy.io import ascii

# %%
hdul = fits.open('final_catalog_updated.fits')
hdul.info()
# Out:
# Filename: final_catalog_updated.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (6705,)   uint8
#   1  /Users/ta298/Downloads/AGN/mara-real_tables/final_my_mle/xray_inf...    1 BinTableHDU    280   6792R x 134C   [K, 12A, D, D, E, D, D, D, D, 8A, 5A, D, D, E, I, E, 13A, 13A, 13A, 156A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, J, E, D, 27A, 22A, 18A, 21A, I, E, E, E, E, I, I, 4A, I, I, D, D, I, I, I, I, E, E, E, E, E, E, I, E, E, I, I, E, E, E, I, I, E, 3A, I, I, 10A, I, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, I, I, 3A, 21A, E, E, E, D, D, D, D, I, J, J]

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                  843 / width of table in bytes
# NAXIS2  =                 6792 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                  134 / number of columns
# EXTNAME = '/Users/ta298/Downloads/AGN/mara-real_tables/final_my_mle/xray_inf...'
# TTYPE1  = 'REC_NO  '           / label for column 1
# TFORM1  = 'K       '           / format for column 1
# TTYPE2  = 'CATALOG '           / label for column 2
# TFORM2  = '12A     '           / format for column 2
# TTYPE3  = 'XRAY_RA '           / label for column 3
# TFORM3  = 'D       '           / format for column 3
# TTYPE4  = 'XRAY_DEC'           / label for column 4
# TFORM4  = 'D       '           / format for column 4
# ...

# %%
from astropy.table import Table
dat = Table.read(hdul[1], format='fits')
df = dat.to_pandas()

# %%
df.head()
# Out:
#    REC_NO       CATALOG     XRAY_RA  XRAY_DEC  XRAY_RA_DEC_ERR     SOFT_FLUX  \
# 0    1392  AO10          333.475555 -0.348052         1.639736  6.728302e-14
# 1    1393  AO10          333.483124 -0.415928         3.951285  8.549677e-14
# 2    1394  AO10          333.527130 -0.268740         2.633521  1.519177e-13
# 3    1395  AO10          333.530151  0.368712         4.362236  8.558770e-15
# 4    1396  AO10          333.530365  0.123070         2.333365  1.604026e-14
#
#    SOFT_DETML     HARD_FLUX     FULL_FLUX ASSOCIATION  ...  \
# 0   84.059120  0.000000e+00  1.644900e-13    SpVJz     ...
# 1   95.350876  1.341292e-13  2.429212e-13    SpVF      ...
# 2  606.051941  7.003428e-14  3.939304e-13    SpVJu     ...
# 3   22.752975  2.874589e-14  3.066302e-14    SpJu      ...
# 4   51.097580  0.000000e+00  4.230737e-14    SpVF      ...
#
#   ASTROMETRICJHK_2015_PHOTOZ  XDQSO_2012_PHOTOZ  RICHARDS_2015_PHOTOZ  \
# 0                      -99.0           -99.0000               -99.000
# ...

# %%
df.columns
# Out:
# Index(['REC_NO', 'CATALOG', 'XRAY_RA', 'XRAY_DEC', 'XRAY_RA_DEC_ERR',
#        'SOFT_FLUX', 'SOFT_DETML', 'HARD_FLUX', 'FULL_FLUX', 'ASSOCIATION',
#        ...
#        'ASTROMETRICJHK_2015_PHOTOZ', 'XDQSO_2012_PHOTOZ',
#        'RICHARDS_2015_PHOTOZ', 'LUMINOSITY_DISTANCE_PHOT', 'LUMINOSITY_PHOT',
#        'LUMINOSITY_DISTANCE_SPEC', 'LUMINOSITY_SPEC', 'DUPLICATION_FLAG',
#        'DUPLICATION_ID_1', 'DUPLICATION_ID_2'],
#       dtype='object', length=134)
